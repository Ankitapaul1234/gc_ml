# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitapaul1234/gc_ml/blob/main/Nan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/test.csv')
dataset.shape
# Out:
# (418, 11)

# %%
dataset.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset.isnull().sum()/dataset.shape[0]*100  #dataset.shape[0]=>row no
# Out:
# PassengerId     0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
dataset.isnull().sum().sum()  #overall data null
# Out:
# 414

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 9.00391474554154

# %%
dataset.notnull().sum().sum()
# Out:
# 4184

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# # **Handel the missing values**

# %%
dataset.shape
# Out:
# (418, 11)

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 9.00391474554154

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# PassengerId     0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
dataset.drop(columns=["Cabin"],inplace=True)  #col drop

# %%
dataset.shape
# Out:
# (418, 10)

# %%
dataset.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
new = dataset.dropna()
sns.heatmap(new.isnull())
plt.show()

# %% [markdown]
# # **Fill the Nan data**

# %%
dataset.fillna(10).head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 32.8+ KB

# %% [markdown]
# #**backward filling("bfill") and forward filling("ffill") for categorical data/object type(string) || axis=1(col) axis=0(row)**

# %%
dataset.fillna(method="bfill",axis=1)
# Out:
# <ipython-input-22-29f1e1a299f3>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill",axis=1)
#     PassengerId Pclass                                          Name     Sex  \
# 0           892      3                              Kelly, Mr. James    male
# 1           893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894      2                     Myles, Mr. Thomas Francis    male
# 3           895      3                              Wirz, Mr. Albert    male
# 4           896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..          ...    ...                                           ...     ...
# 413        1305      3                            Spector, Mr. Woolf    male
# 414        1306      1                  Oliva y Ocana, Dona. Fermina  female
# ...

# %%
dataset.fillna(method="ffill")
# Out:
# <ipython-input-23-04d244a80e37>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill")
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# ...

# %% [markdown]
# # **mod fill**

# %%
dataset['Sex'].mode()[0]
# Out:
# 'male'

# %%
dataset['Sex'].fillna(dataset['Sex'].mode()[0])
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
for i in dataset.select_dtypes(include='object').columns:
  print(i,dataset[i].mode()[0])
# Out:
# Name Abbott, Master. Eugene Joseph
# Sex male
# Ticket PC 17608
# Embarked S

# %%
for i in dataset.select_dtypes(include='object').columns:
  dataset['Sex'].fillna(dataset['Sex'].mode()[0])

# %% [markdown]
# # **Handling missing values using Scikit-learn**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 32.8+ KB

# %%
dataset.select_dtypes(include='float64').columns
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
dataset.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy='mean')  #fill by its mean
ar = si.fit_transform(dataset[['Age','Fare']])

# %%
pd.DataFrame(ar).isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
new_dataset = pd.DataFrame(ar,columns=dataset.select_dtypes(include='float64').columns)

# %%
new_dataset
# Out:
#           Age      Fare
# 0    34.50000    7.8292
# 1    47.00000    7.0000
# 2    62.00000    9.6875
# 3    27.00000    8.6625
# 4    22.00000   12.2875
# ..        ...       ...
# 413  30.27259    8.0500
# 414  39.00000  108.9000
# 415  38.50000    7.2500
# 416  30.27259    8.0500
# 417  30.27259   22.3583
#
# [418 rows x 2 columns]

# %%
new_dataset.isnull().sum()
# Out:
# Age     0
# Fare    0
# dtype: int64

# %%
print(dataset.columns)
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
dataset["Age"].mean()
# Out:
# 30.272590361445783

# %% [markdown]
# **Encoding**  (categocal data -> numerical data)
# have 2 way-->
#  1.get_dumies
# 2.OneHotEncoder(using sckit-learn)

# %%
en_data = dataset[["Gender","Married"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-5e6344e08732> in <cell line: 0>()
# ----> 1 en_data = dataset[["Gender","Married"]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
pd.get_dumies(en_data).info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-7458302f0bdd> in <cell line: 0>()
# ----> 1 pd.get_dumies(en_data).info()
#
# AttributeError: module 'pandas' has no attribute 'get_dumies'

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop="first")
ar = ohe.fit_transform(en_data).toarray()

# %%
pd.DataFrame(ar,columns=["Gender_Female","Gender_Male","Married_no","Married_yes"])

# %% [markdown]
# # **Column Transformer**

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 95   12  Female  104.0    Mild  Bangalore
# 67   65    Male   99.0    Mild  Bangalore
# 74   34  Female  104.0  Strong      Delhi
# 90   59  Female   99.0  Strong      Delhi
# 4    65  Female  101.0    Mild     Mumbai
# ..  ...     ...    ...     ...        ...
# 61   81  Female   98.0  Strong     Mumbai
# 83   17  Female  104.0    Mild    Kolkata
# 30   15    Male  101.0    Mild      Delhi
# 27   33  Female  102.0  Strong      Delhi
# 57   49  Female   99.0  Strong  Bangalore
#
# [80 rows x 5 columns]

# %% [markdown]
# #1. **Aam Zindegi**

# %%
#adding simple imputer to fever col
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])

X_train_fever
# Out:
# array([[104.        ],
#        [ 99.        ],
#        [104.        ],
#        [ 99.        ],
#        [101.        ],
#        [ 98.        ],
#        [101.08219178],
#        [ 98.        ],
#        [104.        ],
#        [101.08219178],
#        [102.        ],
#        [104.        ],
#        [101.        ],
#        [103.        ],
#        [102.        ],
#        [101.        ],
#        [100.        ],
#        [ 99.        ],
#        [101.08219178],
#        [104.        ],
#        [103.        ],
#        [104.        ],
#        [101.08219178],
#        [104.        ],
#        [100.        ],
#        [104.        ],
#        [103.        ],
#        [100.        ],
#        [104.        ],
#        [ 98.        ],
#        [104.        ],
#        [103.        ],
#        [101.        ],
#        [101.        ],
#        [101.        ],
#        [102.        ],
#        [101.08219178],
#        [100.        ],
#        [104.        ],
#        [ 99.        ],
# ...

# %%
# Ordinalencoding -> cough
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(X_train[['cough']])

# also the test data
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape
# Out:
# (80, 1)

# %%
# OneHotEncoding -> gender,city
ohe = OneHotEncoder(drop='first',sparse=False)
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-efc0ed88b09e> in <cell line: 0>()
#       1 # OneHotEncoding -> gender,city
# ----> 2 ohe = OneHotEncoder(drop='first',sparse=False)
#       3 X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])
#       4
#       5 # also the test data
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
# Extracting Age
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)

X_train_transformed.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ca1bac3d7f73> in <cell line: 0>()
# ----> 1 X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
#       2 # also the test data
#       3 X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)
#       4
#       5 X_train_transformed.shape
#
# NameError: name 'X_train_gender_city' is not defined

# %% [markdown]
# # **Mentos zindegi**

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

transformer = ColumnTransformer(transformers=[
    ('tnf1', SimpleImputer(), ['fever']),
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
    ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
], remainder='passthrough')

# %%
transformer.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
