# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitapaul1234/gc_ml/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas on **series**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Seires from lists**

# %%
country = ['India','USA','Japan','France']

pd.Series(country)
# Out:
# 0     India
# 1       USA
# 2     Japan
# 3    France
# dtype: object

# %%
#integers
runs = [13,15,20,78,12]
pd.Series(runs)
# Out:
# 0    13
# 1    15
# 2    20
# 3    78
# 4    12
# dtype: int64

# %%
#custom index
marks = [68,89,85,80]
sub = ['english','maths','science','bengali']

pd.Series(marks,index = sub)
# Out:
# english    68
# maths      89
# science    85
# bengali    80
# dtype: int64

# %%
#add name

amarks = pd.Series(marks,index = sub,name = 'ankita r marks')
amarks
# Out:
# english    68
# maths      89
# science    85
# bengali    80
# Name: ankita r marks, dtype: int64

# %% [markdown]
# # **Series from dict**

# %%
marks ={
    'maths' : 89,
    'eng' : 67,
    'ben': 80,
    'phy' :74
}

marks_series = pd.Series(marks,name = 'ankita r marks')
marks_series
# Out:
# maths    89
# eng      67
# ben      80
# phy      74
# Name: ankita r marks, dtype: int64

# %% [markdown]
# # **Series Attributes**

# %%
#size
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'ankita r marks'

# %%
#is_unique

marks_series.is_unique

pd.Series([1,2,4,1]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'eng', 'ben', 'phy'], dtype='object')

# %%
#values
type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# # **Series using read_csv**

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/content/bollywood.csv',index_col='movie')

# Convert to a Series if the DataFrame has only one column
subs = df.squeeze("columns")

print(type(subs))  # Will be a Series if only one column exists
print(subs)
# Out:
# <class 'pandas.core.series.Series'>
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
import pandas as pd

# Read CSV with no header and ensure it becomes a Series
series = pd.read_csv("/content/bollywood.csv", header=None).squeeze()

print(type(series))  # Should be <class 'pandas.Series'>
print(series)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                          0                 1
# 0                                    movie              lead
# 1                 Uri: The Surgical Strike     Vicky Kaushal
# 2                            Battalion 609       Vicky Ahuja
# 3     The Accidental Prime Minister (film)       Anupam Kher
# 4                          Why Cheat India     Emraan Hashmi
# ...                                    ...               ...
# 1496                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1497                   Aankhen (2002 film)  Amitabh Bachchan
# 1498                       Saathiya (film)      Vivek Oberoi
# 1499                        Company (film)        Ajay Devgn
# 1500                  Awara Paagal Deewana      Akshay Kumar
#
# [1501 rows x 2 columns]

# %% [markdown]
# # **Series Methods**

# %%
#head and tail
subs.head(5)
subs.tail(5)
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
subs.sample(5)
# Out:
# movie
# Game (2011 film)          Abhishek Bachchan
# Aligarh (film)                Sukhesh Arora
# Sonu Ke Titu Ki Sweety        Kartik Aaryan
# Hawas (2004 film)                Shawar Ali
# Mardaani                       Rani Mukerji
# Name: lead, dtype: object

# %%
#value_counts
subs.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
subs.sort_values(ascending=False).head(1).values[0]
# Out:
# 'Zulfi Sayed'

# %%
subs.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
#change in actual data
# subs.sort_values(inplace=True)

# %% [markdown]
# # Series Maths **Methods**

# %%
#count
subs.count()   # the difference between size and count is -----> count does not count Nan(missing values) but size count all
# Out:
# movie    1500
# lead     1500
# dtype: int64

# %%
#sum
subs.sum()  #subs.product()
# Out:
# movie    Uri: The Surgical StrikeBattalion 609The Accid...
# lead     Vicky KaushalVicky AhujaAnupam KherEmraan Hash...
# dtype: object

# %%
#subs.mean()
#print(subs.median())
print(subs.mode())
#print(subs.std())
#print(subs.var())
# Out:
#                      movie          lead
# 0                   Andaaz  Akshay Kumar
# 1           Gabbar Is Back           NaN
# 2  Tanu Weds Manu: Returns           NaN

# %%
subs.describe()
# Out:
#                           movie          lead
# count                      1500          1500
# unique                     1497           566
# top     Tanu Weds Manu: Returns  Akshay Kumar
# freq                          2            48

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame (_df_8 should already be loaded)
# Ensure 'movie' and 'lead' are categorical
_df_8['movie'] = _df_8['movie'].astype(str)
_df_8['lead'] = _df_8['lead'].astype(str)

# Create a contingency table (pivot table) for the 2D categorical distribution
df_2dhist = _df_8.pivot_table(index='lead', columns='movie', aggfunc='size', fill_value=0)

# Plot the heatmap
plt.figure(figsize=(8, 8))
sns.heatmap(df_2dhist, cmap='viridis', annot=True, fmt='d')

plt.xlabel('Movie')
plt.ylabel('Lead')
plt.title('2D Categorical Distribution')

plt.show()

#  Output
# This will generate a heatmap where:

# X-axis (columns) → Movies
# Y-axis (index) → Lead actors
# Cell values → Count of occurrences

# %%
#min,max
print(subs.min())
print(subs.max())
# Out:
# movie    1920 (film)
# lead      Aadar Jain
# dtype: object
# movie    Zor Lagaa Ke...Haiya!
# lead               Zulfi Sayed
# dtype: object

# %% [markdown]
# # Series indexing

# %%
#indexing
x=pd.Series([4,8,1,2,7])
x[1]
# Out:
# 8

# %%
#negetive indexing is not working in pandas
x[-2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -2 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-e4698d532614> in <cell line: 0>()
#       1 #negetive indexing
# ----> 2 x[-2]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
x[1:4]
# Out:
# 1    8
# 2    1
# 3    2
# dtype: int64

# %%
#fancy indexing
x[[1,3]]
# Out:
# 1    8
# 3    2
# dtype: int64

# %%
subs['Mardaani']
# Out:
# 'Rani Mukerji'

# %% [markdown]
# # **Ending series**

# %%
marks_series[0] = 94
print(marks_series)
# Out:
# maths    94
# eng      90
# ben      80
# phy      74
# bio      82
# Name: ankita r marks, dtype: int64
# <ipython-input-76-a5232b1e0d7b>:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[0] = 94

# %%
#if index does not exist
marks_series['bio'] = 82
marks_series
# Out:
# maths    94
# eng      90
# ben      80
# phy      74
# bio      82
# Name: ankita r marks, dtype: int64

# %%
#slicing
marks_series[1:3]=[80,84]
marks_series
# Out:
# maths    94
# eng      80
# ben      84
# phy      74
# bio      82
# Name: ankita r marks, dtype: int64

# %%
#fancy indexing
marks_series[[1,3,4]] = [49,80,86]
marks_series
# Out:
# <ipython-input-101-ccd4e1e06643>:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[[1,3,4]] = [49,80,86]
# maths    94
# eng      49
# ben      84
# phy      80
# bio      86
# Name: ankita r marks, dtype: int64

# %% [markdown]
# # Series with python **functionality**

# %%
#len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(max(subs))
print(min(subs))
# Out:
# 1500
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(marks_series)
# Out:
# [94, 81, 84, 80, 86]

# %%
#dict
dict(marks_series)
# Out:
# {'maths': 94, 'eng': 81, 'ben': 84, 'phy': 80, 'bio': 86}

# %%
#membership operator
'Aankhen (2002 film)' in subs  #for only index value searching not value
# Out:
# True

# %%
subs
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
'Shah Rukh Khan'in subs.values
# Out:
# True

# %%
#looping
for i in subs:
  print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
#looping for values
for i in subs.values:
  print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
#arithmetic operations(broadcasting)
100-marks_series
# Out:
# maths     6
# eng      19
# ben      16
# phy      20
# bio      14
# Name: ankita r marks, dtype: int64

# %%
#realtional operator
marks_series>85
# Out:
# maths     True
# eng      False
# ben      False
# phy      False
# bio       True
# Name: ankita r marks, dtype: bool

# %% [markdown]
# # boolean indexing on series

# %%
#find no of 50's and 100's scored
marks_series[marks_series>=50].size
# Out:
# 4

# %%
#find no of ducks
marks_series[marks_series==0].size
# Out:
# 0

# %%
#find actors who have done more than 20 movies
num_movies = subs.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # **plotting graphs📊 on series**

# %%
num_movies.plot()
# Out:
# <Axes: xlabel='lead'>

# %%
subs.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
subs.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
